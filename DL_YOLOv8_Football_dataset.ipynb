# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.2.50

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.50 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.2/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# ## CLI Basics

# %%
# !mkdir {HOME}/datasets

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip '/content/drive/MyDrive/UFAZ Learning Center/DS_ML_DL_2024_shared/shared resources/datasets/footbal_dataset.zip' -d datasets
# Out:
# Archive:  /content/drive/MyDrive/UFAZ Learning Center/DS_ML_DL_2024_shared/shared resources/datasets/footbal_dataset.zip
#   inflating: datasets/README.dataset.txt
#   inflating: datasets/README.roboflow.txt
#   inflating: datasets/data.yaml
#   inflating: datasets/test/images/08fd33_3_6_png.rf.8be10169272238a48652496ad4824d2e.jpg
#   inflating: datasets/test/images/40cd38_7_6_png.rf.68ef7fcd663cdf0f5b96bacdbcd94e07.jpg
#   inflating: datasets/test/images/42ba34_1_5_png.rf.4337fde8fbe3640cf4351fb41ac9c3ca.jpg
#   inflating: datasets/test/images/42ba34_5_5_png.rf.ceb556bd4c92d41496ae1d8c56600c4a.jpg
#   inflating: datasets/test/images/4b770a_1_4_png.rf.5a45b3b841a06de414ceb802e34c136f.jpg
#   inflating: datasets/test/images/4b770a_1_6_png.rf.ce687822527c0c5c9c1c1661831dcdd5.jpg
#   inflating: datasets/test/images/4b770a_3_6_png.rf.d0d9403f2f73ca0da7a6a1373c02b749.jpg
#   inflating: datasets/test/images/4b770a_3_9_png.rf.31abceb5a1740893ab8a009174cb9811.jpg
# ...

# %% [markdown]
# ## Custom Training

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/datasets/data.yaml epochs=500 imgsz=800 plots=True shear=0.01 degrees=2 perspective=0.001 translate=0.1 fliplr=0.1
# Out:
# Ultralytics YOLOv8.2.50 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ## Validate Custom Model

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt data=/content/datasets/data.yaml
# Out:
# Ultralytics YOLOv8.2.50 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11127132 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/datasets/valid/labels.cache... 43 images, 0 backgrounds, 0 corrupt: 100% 43/43 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:09<00:00,  3.31s/it]
#                    all         43       1025      0.921      0.723      0.821      0.573
#                   ball         39         39          1      0.168       0.39      0.153
#             goalkeeper         32         32      0.759      0.938      0.947      0.726
#                 player         43        853      0.969      0.941      0.987      0.782
#                referee         43        101      0.955      0.844       0.96      0.631
# Speed: 5.6ms preprocess, 28.7ms inference, 0.0ms loss, 61.5ms postprocess per image
# Results saved to runs/detect/val2
# ...

# %% [markdown]
# ## Inference with Custom Model

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt conf=0.25 source=/content/datasets/test/images save=True
# Out:
# Ultralytics YOLOv8.2.50 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11127132 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/19 /content/datasets/test/images/08fd33_3_6_png.rf.8be10169272238a48652496ad4824d2e.jpg: 480x800 20 players, 2 referees, 172.7ms
# image 2/19 /content/datasets/test/images/40cd38_7_6_png.rf.68ef7fcd663cdf0f5b96bacdbcd94e07.jpg: 480x800 1 goalkeeper, 21 players, 1 referee, 15.6ms
# image 3/19 /content/datasets/test/images/42ba34_1_5_png.rf.4337fde8fbe3640cf4351fb41ac9c3ca.jpg: 480x800 1 goalkeeper, 21 players, 3 referees, 15.6ms
# image 4/19 /content/datasets/test/images/42ba34_5_5_png.rf.ceb556bd4c92d41496ae1d8c56600c4a.jpg: 480x800 1 goalkeeper, 20 players, 1 referee, 15.6ms
# image 5/19 /content/datasets/test/images/4b770a_1_4_png.rf.5a45b3b841a06de414ceb802e34c136f.jpg: 480x800 1 goalkeeper, 21 players, 3 referees, 15.6ms
# ...
